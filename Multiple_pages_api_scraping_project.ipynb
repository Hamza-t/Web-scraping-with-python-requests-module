# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamza-t/Web-scraping-with-python-requests-module/blob/main/Multiple_pages_api_scraping_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
results_json
# Out:
# {'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'age_type': 'new',
#   'app': 'web',
#   'body_style': None,
#   'cpo': False,
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'year': 2022},
#  'html': {'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="14"><a>14</a></li><li data-page="15"><a>15</a></li><li data-page="2" class="next"><a>Next</a></li></ul>',
#   'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA0JF049255"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--owv7hvGJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21185133/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2018 Tesla Model 3 Long Range White 5YJ3E1EA0JF049255\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2018 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n15,647 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Fairfield, CA</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$48,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $706/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EA2JF123369"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--hLOdYf3O--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-3124264772727906163-1024x768.jpeg)\' title=\'used 2018 Tesla Model 3 Long Range Black 5YJ3E1EA2JF123369\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2018 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n23,570 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Online Only</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$44,450</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $641/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+x#vin=5YJXCAE25KF160448"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--wrNCzXkI--/c_fill,f_auto,q_auto,w_3 ...
#  'make_model_name': 'Tesla',
#  'search_results': [{'accepts_leads': True,
#    'always_ask_for_zip': True,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Fairfield',
#    'click_off': False,
#    'clickoff_url': 'https://www.carmax.com/car/21185133?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'cpl_value': 15,
#    'created_at': 1633066151,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'display_color': '',
#    'distance_from_origin': 41,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJ3E1EA0JF049255',
#    'id': 228637212,
#    'is_hot': False,
#    'lat': 38.27872113250454,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.0043812304184,
#    'make': 'Tesla',
#    'mileage': '15,647 Miles',
#    'mileage_unformatted': 15647,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$48,998',
#    'price_unformatted': 48998,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21185133/1.jpg?width=1024&watermark=LYCG_1a',
#    'provider': None,
#    'provider_group_id': 149,
#    'provider_id': 146,
#    'provider_name': 'carmax',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--owv7hvGJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21185133/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#     'dealer_name': 'CarMax Fairfield',
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'experience': 'local',
#     'id_from_provider': '5YJ3E1EA0JF049255',
#     'remote_dealer_id': '6048',
#     'remote_sku': '21185133',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF049255',
#    'vin': '5YJ3E1EA0JF049255',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c199382?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1633135428,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA2JF123369',
#    'id': 228713731,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '23,570 Miles',
#    'mileage_unformatted': 23570,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$44,450',
#    'price_unformatted': 44450,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-3124264772727906163-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hLOdYf3O--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-3124264772727906163-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313751979',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c199382',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF123369',
#    'vin': '5YJ3E1EA2JF123369',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Vallejo',
#    'click_off': False,
#    'clickoff_url': '',
#    'cpl_value': 3,
#    'created_at': 1629679870,
#    'dealer_name': 'AutoLinx Inc.',
#    'display_color': '',
#    'distance_from_origin': 26,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJXCAE25KF160448',
#    'id': 226028339,
#    'is_hot': False,
#    'lat': 38.1348,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.256,
#    'make': 'Tesla',
#    'mileage': '40,855 Miles',
#    'mileage_unformatted': 40855,
#    'model': 'Model X',
#    'model_id': 2101,
#    'open_in_new_window': False,
#    'partner_type': 'metasearch',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$86,800',
#    'price_unformatted': 86800,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/29/08/43/2019_tesla_model_x-pic-6334660806199204552-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 227,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': True,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wrNCzXkI--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/29/08/43/2019_tesla_model_x-pic-6334660806199204552-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': None,
#     'dealer_group_uuid': None,
#     'dealer_name': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'experience': 'local',
#     'id_from_provider': '310610998',
#     'remote_dealer_id': '335398',
#     'remote_sku': '4743',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': '75D',
#    'vdp_url': '/tesla-model+x#vin=5YJXCAE25KF160448',
#    'vin': '5YJXCAE25KF160448',
#    'year': 2019},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c103759?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1633049200,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA8LF614659',
#    'id': 228616269,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '3,483 Miles',
#    'mileage_unformatted': 3483,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$44,950',
#    'price_unformatted': 44950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-4493980457001804847-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--nArNLW54--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-4493980457001804847-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313645454',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c103759',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Standard Range Plus',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8LF614659',
#    'vin': '5YJ3E1EA8LF614659',
#    'year': 2020},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c129964?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1633049200,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJXCDE23HF051108',
#    'id': 228616270,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '35,613 Miles',
#    'mileage_unformatted': 35613,
#    'model': 'Model X',
#    'model_id': 2101,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$74,950',
#    'price_unformatted': 74950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2017_tesla_model_x-pic-2023715419740927955-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pf5aSWKK--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2017_tesla_model_x-pic-2023715419740927955-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313645451',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c129964',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': '100D',
#    'vdp_url': '/tesla-model+x#vin=5YJXCDE23HF051108',
#    'vin': '5YJXCDE23HF051108',
#    'year': 2017},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c118444?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1631234921,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EB8LF746412',
#    'id': 227230093,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '9,739 Miles',
#    'mileage_unformatted': 9739,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$50,450',
#    'price_unformatted': 50450,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-790084438027771403-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--LNTlfyEl--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-790084438027771403-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '312112689',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c118444',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8LF746412',
#    'vin': '5YJ3E1EB8LF746412',
#    'year': 2020},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c1993497?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1631717877,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA0JF039437',
#    'id': 227561031,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '19,632 Miles',
#    'mileage_unformatted': 19632,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$43,450',
#    'price_unformatted': 43450,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-723037919982711943-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--cEwGOWum--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-723037919982711943-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '312531347',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c1993497',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF039437',
#    'vin': '5YJ3E1EA0JF039437',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c1738739?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1631976665,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA3LF613810',
#    'id': 227809401,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '11,091 Miles',
#    'mileage_unformatted': 11091,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$42,950',
#    'price_unformatted': 42950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-9012188125691048034-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--N4s3ZuDC--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-9012188125691048034-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '312794904',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c1738739',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Standard Range Plus',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3LF613810',
#    'vin': '5YJ3E1EA3LF613810',
#    'year': 2020},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c1097457?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1633481130,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA0JF010746',
#    'id': 228900238,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '15,451 Miles',
#    'mileage_unformatted': 15451,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$44,950',
#    'price_unformatted': 44950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-511429249239531364-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5p4uqaLq--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-511429249239531364-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313975112',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c1097457',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF010746',
#    'vin': '5YJ3E1EA0JF010746',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Concord',
#    'click_off': False,
#    'clickoff_url': '',
#    'cpl_value': 3,
#    'created_at': 1631203234,
#    'dealer_name': 'Future Chrysler Dodge Jeep Ram Of Concord',
#    'display_color': '',
#    'distance_from_origin': 25,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJ3E1EA8JF101800',
#    'id': 227202892,
#    'is_hot': False,
#    'lat': 37.9991,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.054,
#    'make': 'Tesla',
#    'mileage': '31,331 Miles',
#    'mileage_unformatted': 31331,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'metasearch',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$48,950',
#    'price_unformatted': 48950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/16/13/11/2018_tesla_model_3-pic-3489799002218852578-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 228,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': True,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5ecwUqN4--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/09/16/13/11/2018_tesla_model_3-pic-3489799002218852578-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': None,
#     'dealer_group_uuid': None,
#     'dealer_name': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'experience': 'local',
#     'id_from_provider': '312095203',
#     'remote_dealer_id': '438930',
#     'remote_sku': 'P50373',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF101800',
#    'vin': '5YJ3E1EA8JF101800',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Livermore',
#    'click_off': False,
#    'clickoff_url': '',
#    'cpl_value': 3,
#    'created_at': 1630509141,
#    'dealer_name': 'Livermore Ford Lincoln',
#    'display_color': '',
#    'distance_from_origin': 33,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJYGDED2MF133643',
#    'id': 226627368,
#    'is_hot': False,
#    'lat': 37.700083,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -121.806922,
#    'make': 'Tesla',
#    'mileage': '1,809 Miles',
#    'mileage_unformatted': 1809,
#    'model': 'Model Y',
#    'model_id': 2357,
#    'open_in_new_window': False,
#    'partner_type': 'metasearch',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$63,572',
#    'price_unformatted': 63572,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/06/01/51/2021_tesla_model_y-pic-1102082679258296479-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 228,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': True,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OPCECClz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/09/06/01/51/2021_tesla_model_y-pic-1102082679258296479-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': None,
#     'dealer_group_uuid': None,
#     'dealer_name': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'experience': 'local',
#     'id_from_provider': '311539049',
#     'remote_dealer_id': '286449',
#     'remote_sku': 'P8682',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Standard Range',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDED2MF133643',
#    'vin': '5YJYGDED2MF133643',
#    'year': 2021},
#   {'accepts_leads': True,
#    'always_ask_for_zip': True,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Fremont',
#    'click_off': False,
#    'clickoff_url': 'https://www.carmax.com/car/21038700?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'cpl_value': 15,
#    'created_at': 1632202138,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'display_color': '',
#    'distance_from_origin': 30,
#    'email_opt_default': True,
#    'experience': 'local_if_nearby',
#    'href_target': '/listings/5YJ3E1EB7KF193931',
#    'id': 227933288,
#    'is_hot': False,
#    'lat': 37.50613267061532,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -121.965889235115,
#    'make': 'Tesla',
#    'mileage': '29,863 Miles',
#    'mileage_unformatted': 29863,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$47,998',
#    'price_unformatted': 47998,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038700/1.jpg?width=1024&watermark=LYCG_1a',
#    'provider': None,
#    'provider_group_id': 149,
#    'provider_id': 146,
#    'provider_name': 'carmax',
#    'quick_picks_eligible': False,
#    'recent_price_drop': None,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2nPdrsJS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038700/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#     'dealer_name': 'CarMax Fremont',
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'experience': 'local',
#     'id_from_provider': '5YJ3E1EB7KF193931',
#     'remote_dealer_id': '6071',
#     'remote_sku': '21038700',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF193931',
#    'vin': '5YJ3E1EB7KF193931',
#    'year': 2019},
#   {'accepts_leads': True,
#    'always_ask_for_zip': True,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Fairfield',
#    'click_off': False,
#    'clickoff_url': 'https://www.carmax.com/car/21038079?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'cpl_value': 15,
#    'created_at': 1629945690,
#    'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#    'display_color': '',
#    'distance_from_origin': 41,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJ3E1EC3LF627028',
#    'id': 226212821,
#    'is_hot': False,
#    'lat': 38.27872113250454,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.0043812304184,
#    'make': 'Tesla',
#    'mileage': '11,537 Miles',
#    'mileage_unformatted': 11537,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$57,998',
#    'price_unformatted': 57998,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038079/1.jpg?width=1024&watermark=LYCG_1a',
#    'provider': None,
#    'provider_group_id': 149,
#    'provider_id': 146,
#    'provider_name': 'carmax',
#    'quick_picks_eligible': False,
#    'recent_price_drop': None,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tgidf9k4--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038079/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#     'dealer_name': 'CarMax Fairfield',
#     'dealer_unique_name': 'carmax_fairfield',
#     'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#     'experience': 'local',
#     'id_from_provider': '5YJ3E1EC3LF627028',
#     'remote_dealer_id': '6048',
#     'remote_sku': '21038079',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Performance',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EC3LF627028',
#    'vin': '5YJ3E1EC3LF627028',
#    'year': 2020},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c166930?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1632876266,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EBXKF194653',
#    'id': 228451853,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '30,346 Miles',
#    'mileage_unformatted': 30346,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$46,950',
#    'price_unformatted': 46950,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-8511247340386441522-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--bHG9lckS--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-8511247340386441522-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313451413',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c166930',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXKF194653',
#    'vin': '5YJ3E1EBXKF194653',
#    'year': 2019},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c148999?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1632409239,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EBXKF191350',
#    'id': 228104413,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '41,902 Miles',
#    'mileage_unformatted': 41902,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$46,450',
#    'price_unformatted': 46450,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-5494211851504527932-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--h0piZd6a--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-5494211851504527932-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '313124952',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c148999',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXKF191350',
#    'vin': '5YJ3E1EBXKF191350',
#    'year': 2019},
#   {'accepts_leads': True,
#    'always_ask_for_zip': True,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Santa Rosa',
#    'click_off': False,
#    'clickoff_url': 'https://www.carmax.com/car/21164764?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'cpl_value': 15,
#    'created_at': 1633498484,
#    'dealer_name': 'CarMax Santa Rosa - Now Open',
#    'display_color': '',
#    'distance_from_origin': 46,
#    'email_opt_default': True,
#    'experience': 'local_if_nearby',
#    'href_target': '/listings/5YJ3E1EB5KF465067',
#    'id': 228940039,
#    'is_hot': False,
#    'lat': 38.39414581921437,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.7426700990229,
#    'make': 'Tesla',
#    'mileage': '21,256 Miles',
#    'mileage_unformatted': 21256,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$49,998',
#    'price_unformatted': 49998,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21164764/1.jpg?width=1024&watermark=LYCG_1a',
#    'provider': None,
#    'provider_group_id': 149,
#    'provider_id': 146,
#    'provider_name': 'carmax',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--yBgGISnc--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21164764/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#     'dealer_name': 'CarMax Santa Rosa',
#     'dealer_unique_name': 'carmax_santa_rosa',
#     'dealer_uuid': '65995b5c-37dd-4c3e-9d1f-1e4cddf4565c',
#     'experience': 'local',
#     'id_from_provider': '5YJ3E1EB5KF465067',
#     'remote_dealer_id': '6077',
#     'remote_sku': '21164764',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5KF465067',
#    'vin': '5YJ3E1EB5KF465067',
#    'year': 2019},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c1285558?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1628729172,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EBXLF711130',
#    'id': 225288599,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '8,039 Miles',
#    'mileage_unformatted': 8039,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$51,450',
#    'price_unformatted': 51450,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-5738853240449663700-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--782u-hWt--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-5738853240449663700-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '309968030',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c1285558',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF711130',
#    'vin': '5YJ3E1EBXLF711130',
#    'year': 2020},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'Oakland',
#    'click_off': False,
#    'clickoff_url': '',
#    'cpl_value': 3,
#    'created_at': 1633480650,
#    'dealer_name': 'One Toyota Of Oakland',
#    'display_color': '',
#    'distance_from_origin': 12,
#    'email_opt_default': True,
#    'experience': 'local',
#    'href_target': '/listings/5YJ3E1EA7JF164757',
#    'id': 228898165,
#    'is_hot': False,
#    'lat': 37.7406,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.198,
#    'make': 'Tesla',
#    'mileage': '32,766 Miles',
#    'mileage_unformatted': 32766,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'metasearch',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$42,861',
#    'price_unformatted': 42861,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/08/02/27/2018_tesla_model_3-pic-4243662948642171140-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 228,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': True,
#    'recent_price_drop': True,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--M5yXagJL--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/08/02/27/2018_tesla_model_3-pic-4243662948642171140-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': None,
#     'dealer_group_uuid': None,
#     'dealer_name': None,
#     'dealer_unique_name': None,
#     'dealer_uuid': None,
#     'experience': 'local',
#     'id_from_provider': '313997286',
#     'remote_dealer_id': '280270',
#     'remote_sku': 'P10638',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Standard',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF164757',
#    'vin': '5YJ3E1EA7JF164757',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': True,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': None},
#    'city': 'Pleasanton',
#    'click_off': False,
#    'clickoff_url': 'https://www.carmax.com/car/21240925?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'cpl_value': 15,
#    'created_at': 1633486789,
#    'dealer_name': 'CarMax Pleasanton - Now Open',
#    'display_color': '',
#    'distance_from_origin': 28,
#    'email_opt_default': True,
#    'experience': 'local_if_nearby',
#    'href_target': '/listings/5YJ3E1EB2JF130847',
#    'id': 228926698,
#    'is_hot': False,
#    'lat': 37.67825483705325,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -121.9129676305049,
#    'make': 'Tesla',
#    'mileage': '23,676 Miles',
#    'mileage_unformatted': 23676,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$47,998',
#    'price_unformatted': 47998,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21240925/1.jpg?width=1024&watermark=LYCG_1a',
#    'provider': None,
#    'provider_group_id': 149,
#    'provider_id': 146,
#    'provider_name': 'carmax',
#    'quick_picks_eligible': False,
#    'recent_price_drop': False,
#    'regional': False,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wuswKLdU--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21240925/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#     'dealer_name': 'CarMax Pleasanton',
#     'dealer_unique_name': 'carmax_pleasanton',
#     'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#     'experience': 'local',
#     'id_from_provider': '5YJ3E1EB2JF130847',
#     'remote_dealer_id': '6068',
#     'remote_sku': '21240925',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Long Range',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2JF130847',
#    'vin': '5YJ3E1EB2JF130847',
#    'year': 2018},
#   {'accepts_leads': True,
#    'always_ask_for_zip': False,
#    'available_nationwide': False,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'city': 'South San Francisco',
#    'click_off': False,
#    'clickoff_url': 'https://www.shift.com/car/c1691660?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'cpl_value': 15,
#    'created_at': 1628124596,
#    'dealer_name': 'Shift SF - Test Drives Delivered To You',
#    'display_color': '',
#    'distance_from_origin': 9,
#    'email_opt_default': True,
#    'experience': 'regional',
#    'href_target': '/listings/5YJ3E1EA3JF156817',
#    'id': 224824493,
#    'is_hot': False,
#    'lat': 37.6397,
#    'listimate_category': None,
#    'listimate_text': None,
#    'listing_id': None,
#    'lon': -122.416,
#    'make': 'Tesla',
#    'mileage': '15,835 Miles',
#    'mileage_unformatted': 15835,
#    'model': 'Model 3',
#    'model_id': 2217,
#    'open_in_new_window': False,
#    'partner_type': 'dealer_direct',
#    'photo_urls': [],
#    'pre_check_thankyou': True,
#    'price': '$39,500',
#    'price_unformatted': 39500,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-75754149688681297-1024x768.jpeg',
#    'provider': None,
#    'provider_group_id': 231,
#    'provider_id': 199,
#    'provider_name': 'car_gurus',
#    'quick_picks_eligible': False,
#    'recent_price_drop': True,
#    'regional': True,
#    'relative_price_difference': None,
#    'show_financing_checkbox': None,
#    'show_message_box': None,
#    'show_new_mileage': False,
#    'show_rsrp': True,
#    'show_thankyou_page': False,
#    'state': 'CA',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--k9Gij6CN--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-75754149688681297-1024x768.jpeg',
#    'time_on_market': None,
#    'total_price_change': None,
#    'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#     'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#     'dealer_name': 'Shift SF - Test Drives Delivered to You',
#     'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#     'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#     'experience': 'regional',
#     'id_from_provider': '309463611',
#     'remote_dealer_id': '413397',
#     'remote_sku': 'c1691660',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None},
#    'trim': 'Standard',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF156817',
#    'vin': '5YJ3E1EA3JF156817',
#    'year': 2018}],
#  'total_results_count': 313,
#  'trims': []}

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# model
# mileage
# year
# dealer name
# price

# %%
results_json['search_results']
# Out:
# [{'accepts_leads': True,
#   'always_ask_for_zip': True,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Fairfield',
#   'click_off': False,
#   'clickoff_url': 'https://www.carmax.com/car/21185133?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'cpl_value': 15,
#   'created_at': 1633066151,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'display_color': '',
#   'distance_from_origin': 41,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJ3E1EA0JF049255',
#   'id': 228637212,
#   'is_hot': False,
#   'lat': 38.27872113250454,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.0043812304184,
#   'make': 'Tesla',
#   'mileage': '15,647 Miles',
#   'mileage_unformatted': 15647,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$48,998',
#   'price_unformatted': 48998,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21185133/1.jpg?width=1024&watermark=LYCG_1a',
#   'provider': None,
#   'provider_group_id': 149,
#   'provider_id': 146,
#   'provider_name': 'carmax',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--owv7hvGJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21185133/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#    'dealer_name': 'CarMax Fairfield',
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'experience': 'local',
#    'id_from_provider': '5YJ3E1EA0JF049255',
#    'remote_dealer_id': '6048',
#    'remote_sku': '21185133',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF049255',
#   'vin': '5YJ3E1EA0JF049255',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c199382?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1633135428,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA2JF123369',
#   'id': 228713731,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '23,570 Miles',
#   'mileage_unformatted': 23570,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$44,450',
#   'price_unformatted': 44450,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-3124264772727906163-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--hLOdYf3O--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-3124264772727906163-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313751979',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c199382',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2JF123369',
#   'vin': '5YJ3E1EA2JF123369',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Vallejo',
#   'click_off': False,
#   'clickoff_url': '',
#   'cpl_value': 3,
#   'created_at': 1629679870,
#   'dealer_name': 'AutoLinx Inc.',
#   'display_color': '',
#   'distance_from_origin': 26,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJXCAE25KF160448',
#   'id': 226028339,
#   'is_hot': False,
#   'lat': 38.1348,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.256,
#   'make': 'Tesla',
#   'mileage': '40,855 Miles',
#   'mileage_unformatted': 40855,
#   'model': 'Model X',
#   'model_id': 2101,
#   'open_in_new_window': False,
#   'partner_type': 'metasearch',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$86,800',
#   'price_unformatted': 86800,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/29/08/43/2019_tesla_model_x-pic-6334660806199204552-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 227,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': True,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wrNCzXkI--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/29/08/43/2019_tesla_model_x-pic-6334660806199204552-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': None,
#    'dealer_group_uuid': None,
#    'dealer_name': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'experience': 'local',
#    'id_from_provider': '310610998',
#    'remote_dealer_id': '335398',
#    'remote_sku': '4743',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': '75D',
#   'vdp_url': '/tesla-model+x#vin=5YJXCAE25KF160448',
#   'vin': '5YJXCAE25KF160448',
#   'year': 2019},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c103759?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1633049200,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA8LF614659',
#   'id': 228616269,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '3,483 Miles',
#   'mileage_unformatted': 3483,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$44,950',
#   'price_unformatted': 44950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-4493980457001804847-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--nArNLW54--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-4493980457001804847-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313645454',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c103759',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Standard Range Plus',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8LF614659',
#   'vin': '5YJ3E1EA8LF614659',
#   'year': 2020},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c129964?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1633049200,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJXCDE23HF051108',
#   'id': 228616270,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '35,613 Miles',
#   'mileage_unformatted': 35613,
#   'model': 'Model X',
#   'model_id': 2101,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$74,950',
#   'price_unformatted': 74950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2017_tesla_model_x-pic-2023715419740927955-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pf5aSWKK--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2017_tesla_model_x-pic-2023715419740927955-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313645451',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c129964',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': '100D',
#   'vdp_url': '/tesla-model+x#vin=5YJXCDE23HF051108',
#   'vin': '5YJXCDE23HF051108',
#   'year': 2017},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c118444?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1631234921,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EB8LF746412',
#   'id': 227230093,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '9,739 Miles',
#   'mileage_unformatted': 9739,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$50,450',
#   'price_unformatted': 50450,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-790084438027771403-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--LNTlfyEl--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-790084438027771403-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '312112689',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c118444',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB8LF746412',
#   'vin': '5YJ3E1EB8LF746412',
#   'year': 2020},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c1993497?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1631717877,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA0JF039437',
#   'id': 227561031,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '19,632 Miles',
#   'mileage_unformatted': 19632,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$43,450',
#   'price_unformatted': 43450,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-723037919982711943-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--cEwGOWum--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-723037919982711943-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '312531347',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c1993497',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF039437',
#   'vin': '5YJ3E1EA0JF039437',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c1738739?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1631976665,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA3LF613810',
#   'id': 227809401,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '11,091 Miles',
#   'mileage_unformatted': 11091,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$42,950',
#   'price_unformatted': 42950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-9012188125691048034-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--N4s3ZuDC--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-9012188125691048034-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '312794904',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c1738739',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Standard Range Plus',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3LF613810',
#   'vin': '5YJ3E1EA3LF613810',
#   'year': 2020},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c1097457?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1633481130,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA0JF010746',
#   'id': 228900238,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '15,451 Miles',
#   'mileage_unformatted': 15451,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$44,950',
#   'price_unformatted': 44950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-511429249239531364-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5p4uqaLq--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-511429249239531364-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313975112',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c1097457',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF010746',
#   'vin': '5YJ3E1EA0JF010746',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Concord',
#   'click_off': False,
#   'clickoff_url': '',
#   'cpl_value': 3,
#   'created_at': 1631203234,
#   'dealer_name': 'Future Chrysler Dodge Jeep Ram Of Concord',
#   'display_color': '',
#   'distance_from_origin': 25,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJ3E1EA8JF101800',
#   'id': 227202892,
#   'is_hot': False,
#   'lat': 37.9991,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.054,
#   'make': 'Tesla',
#   'mileage': '31,331 Miles',
#   'mileage_unformatted': 31331,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'metasearch',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$48,950',
#   'price_unformatted': 48950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/16/13/11/2018_tesla_model_3-pic-3489799002218852578-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 228,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': True,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5ecwUqN4--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/09/16/13/11/2018_tesla_model_3-pic-3489799002218852578-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': None,
#    'dealer_group_uuid': None,
#    'dealer_name': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'experience': 'local',
#    'id_from_provider': '312095203',
#    'remote_dealer_id': '438930',
#    'remote_sku': 'P50373',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8JF101800',
#   'vin': '5YJ3E1EA8JF101800',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Livermore',
#   'click_off': False,
#   'clickoff_url': '',
#   'cpl_value': 3,
#   'created_at': 1630509141,
#   'dealer_name': 'Livermore Ford Lincoln',
#   'display_color': '',
#   'distance_from_origin': 33,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJYGDED2MF133643',
#   'id': 226627368,
#   'is_hot': False,
#   'lat': 37.700083,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -121.806922,
#   'make': 'Tesla',
#   'mileage': '1,809 Miles',
#   'mileage_unformatted': 1809,
#   'model': 'Model Y',
#   'model_id': 2357,
#   'open_in_new_window': False,
#   'partner_type': 'metasearch',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$63,572',
#   'price_unformatted': 63572,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/09/06/01/51/2021_tesla_model_y-pic-1102082679258296479-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 228,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': True,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OPCECClz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/09/06/01/51/2021_tesla_model_y-pic-1102082679258296479-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': None,
#    'dealer_group_uuid': None,
#    'dealer_name': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'experience': 'local',
#    'id_from_provider': '311539049',
#    'remote_dealer_id': '286449',
#    'remote_sku': 'P8682',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Standard Range',
#   'vdp_url': '/tesla-model+y#vin=5YJYGDED2MF133643',
#   'vin': '5YJYGDED2MF133643',
#   'year': 2021},
#  {'accepts_leads': True,
#   'always_ask_for_zip': True,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Fremont',
#   'click_off': False,
#   'clickoff_url': 'https://www.carmax.com/car/21038700?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'cpl_value': 15,
#   'created_at': 1632202138,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'display_color': '',
#   'distance_from_origin': 30,
#   'email_opt_default': True,
#   'experience': 'local_if_nearby',
#   'href_target': '/listings/5YJ3E1EB7KF193931',
#   'id': 227933288,
#   'is_hot': False,
#   'lat': 37.50613267061532,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -121.965889235115,
#   'make': 'Tesla',
#   'mileage': '29,863 Miles',
#   'mileage_unformatted': 29863,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$47,998',
#   'price_unformatted': 47998,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038700/1.jpg?width=1024&watermark=LYCG_1a',
#   'provider': None,
#   'provider_group_id': 149,
#   'provider_id': 146,
#   'provider_name': 'carmax',
#   'quick_picks_eligible': False,
#   'recent_price_drop': None,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2nPdrsJS--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038700/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#    'dealer_name': 'CarMax Fremont',
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'experience': 'local',
#    'id_from_provider': '5YJ3E1EB7KF193931',
#    'remote_dealer_id': '6071',
#    'remote_sku': '21038700',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7KF193931',
#   'vin': '5YJ3E1EB7KF193931',
#   'year': 2019},
#  {'accepts_leads': True,
#   'always_ask_for_zip': True,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Fairfield',
#   'click_off': False,
#   'clickoff_url': 'https://www.carmax.com/car/21038079?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'cpl_value': 15,
#   'created_at': 1629945690,
#   'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#   'display_color': '',
#   'distance_from_origin': 41,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJ3E1EC3LF627028',
#   'id': 226212821,
#   'is_hot': False,
#   'lat': 38.27872113250454,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.0043812304184,
#   'make': 'Tesla',
#   'mileage': '11,537 Miles',
#   'mileage_unformatted': 11537,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$57,998',
#   'price_unformatted': 57998,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21038079/1.jpg?width=1024&watermark=LYCG_1a',
#   'provider': None,
#   'provider_group_id': 149,
#   'provider_id': 146,
#   'provider_name': 'carmax',
#   'quick_picks_eligible': False,
#   'recent_price_drop': None,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--tgidf9k4--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21038079/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#    'dealer_name': 'CarMax Fairfield',
#    'dealer_unique_name': 'carmax_fairfield',
#    'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#    'experience': 'local',
#    'id_from_provider': '5YJ3E1EC3LF627028',
#    'remote_dealer_id': '6048',
#    'remote_sku': '21038079',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Performance',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EC3LF627028',
#   'vin': '5YJ3E1EC3LF627028',
#   'year': 2020},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c166930?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1632876266,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EBXKF194653',
#   'id': 228451853,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '30,346 Miles',
#   'mileage_unformatted': 30346,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$46,950',
#   'price_unformatted': 46950,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-8511247340386441522-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--bHG9lckS--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-8511247340386441522-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313451413',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c166930',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXKF194653',
#   'vin': '5YJ3E1EBXKF194653',
#   'year': 2019},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c148999?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1632409239,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EBXKF191350',
#   'id': 228104413,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '41,902 Miles',
#   'mileage_unformatted': 41902,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$46,450',
#   'price_unformatted': 46450,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-5494211851504527932-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--h0piZd6a--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2019_tesla_model_3-pic-5494211851504527932-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '313124952',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c148999',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXKF191350',
#   'vin': '5YJ3E1EBXKF191350',
#   'year': 2019},
#  {'accepts_leads': True,
#   'always_ask_for_zip': True,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Santa Rosa',
#   'click_off': False,
#   'clickoff_url': 'https://www.carmax.com/car/21164764?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'cpl_value': 15,
#   'created_at': 1633498484,
#   'dealer_name': 'CarMax Santa Rosa - Now Open',
#   'display_color': '',
#   'distance_from_origin': 46,
#   'email_opt_default': True,
#   'experience': 'local_if_nearby',
#   'href_target': '/listings/5YJ3E1EB5KF465067',
#   'id': 228940039,
#   'is_hot': False,
#   'lat': 38.39414581921437,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.7426700990229,
#   'make': 'Tesla',
#   'mileage': '21,256 Miles',
#   'mileage_unformatted': 21256,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$49,998',
#   'price_unformatted': 49998,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21164764/1.jpg?width=1024&watermark=LYCG_1a',
#   'provider': None,
#   'provider_group_id': 149,
#   'provider_id': 146,
#   'provider_name': 'carmax',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--yBgGISnc--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21164764/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#    'dealer_name': 'CarMax Santa Rosa',
#    'dealer_unique_name': 'carmax_santa_rosa',
#    'dealer_uuid': '65995b5c-37dd-4c3e-9d1f-1e4cddf4565c',
#    'experience': 'local',
#    'id_from_provider': '5YJ3E1EB5KF465067',
#    'remote_dealer_id': '6077',
#    'remote_sku': '21164764',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5KF465067',
#   'vin': '5YJ3E1EB5KF465067',
#   'year': 2019},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c1285558?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1628729172,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EBXLF711130',
#   'id': 225288599,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '8,039 Miles',
#   'mileage_unformatted': 8039,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$51,450',
#   'price_unformatted': 51450,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-5738853240449663700-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--782u-hWt--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2020_tesla_model_3-pic-5738853240449663700-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '309968030',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c1285558',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXLF711130',
#   'vin': '5YJ3E1EBXLF711130',
#   'year': 2020},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'Oakland',
#   'click_off': False,
#   'clickoff_url': '',
#   'cpl_value': 3,
#   'created_at': 1633480650,
#   'dealer_name': 'One Toyota Of Oakland',
#   'display_color': '',
#   'distance_from_origin': 12,
#   'email_opt_default': True,
#   'experience': 'local',
#   'href_target': '/listings/5YJ3E1EA7JF164757',
#   'id': 228898165,
#   'is_hot': False,
#   'lat': 37.7406,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.198,
#   'make': 'Tesla',
#   'mileage': '32,766 Miles',
#   'mileage_unformatted': 32766,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'metasearch',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$42,861',
#   'price_unformatted': 42861,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/08/02/27/2018_tesla_model_3-pic-4243662948642171140-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 228,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': True,
#   'recent_price_drop': True,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--M5yXagJL--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/08/02/27/2018_tesla_model_3-pic-4243662948642171140-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': None,
#    'dealer_group_uuid': None,
#    'dealer_name': None,
#    'dealer_unique_name': None,
#    'dealer_uuid': None,
#    'experience': 'local',
#    'id_from_provider': '313997286',
#    'remote_dealer_id': '280270',
#    'remote_sku': 'P10638',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Standard',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7JF164757',
#   'vin': '5YJ3E1EA7JF164757',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': True,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': None},
#   'city': 'Pleasanton',
#   'click_off': False,
#   'clickoff_url': 'https://www.carmax.com/car/21240925?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'cpl_value': 15,
#   'created_at': 1633486789,
#   'dealer_name': 'CarMax Pleasanton - Now Open',
#   'display_color': '',
#   'distance_from_origin': 28,
#   'email_opt_default': True,
#   'experience': 'local_if_nearby',
#   'href_target': '/listings/5YJ3E1EB2JF130847',
#   'id': 228926698,
#   'is_hot': False,
#   'lat': 37.67825483705325,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -121.9129676305049,
#   'make': 'Tesla',
#   'mileage': '23,676 Miles',
#   'mileage_unformatted': 23676,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$47,998',
#   'price_unformatted': 47998,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21240925/1.jpg?width=1024&watermark=LYCG_1a',
#   'provider': None,
#   'provider_group_id': 149,
#   'provider_id': 146,
#   'provider_name': 'carmax',
#   'quick_picks_eligible': False,
#   'recent_price_drop': False,
#   'regional': False,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--wuswKLdU--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21240925/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#    'dealer_name': 'CarMax Pleasanton',
#    'dealer_unique_name': 'carmax_pleasanton',
#    'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#    'experience': 'local',
#    'id_from_provider': '5YJ3E1EB2JF130847',
#    'remote_dealer_id': '6068',
#    'remote_sku': '21240925',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Long Range',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2JF130847',
#   'vin': '5YJ3E1EB2JF130847',
#   'year': 2018},
#  {'accepts_leads': True,
#   'always_ask_for_zip': False,
#   'available_nationwide': False,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'city': 'South San Francisco',
#   'click_off': False,
#   'clickoff_url': 'https://www.shift.com/car/c1691660?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'cpl_value': 15,
#   'created_at': 1628124596,
#   'dealer_name': 'Shift SF - Test Drives Delivered To You',
#   'display_color': '',
#   'distance_from_origin': 9,
#   'email_opt_default': True,
#   'experience': 'regional',
#   'href_target': '/listings/5YJ3E1EA3JF156817',
#   'id': 224824493,
#   'is_hot': False,
#   'lat': 37.6397,
#   'listimate_category': None,
#   'listimate_text': None,
#   'listing_id': None,
#   'lon': -122.416,
#   'make': 'Tesla',
#   'mileage': '15,835 Miles',
#   'mileage_unformatted': 15835,
#   'model': 'Model 3',
#   'model_id': 2217,
#   'open_in_new_window': False,
#   'partner_type': 'dealer_direct',
#   'photo_urls': [],
#   'pre_check_thankyou': True,
#   'price': '$39,500',
#   'price_unformatted': 39500,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-75754149688681297-1024x768.jpeg',
#   'provider': None,
#   'provider_group_id': 231,
#   'provider_id': 199,
#   'provider_name': 'car_gurus',
#   'quick_picks_eligible': False,
#   'recent_price_drop': True,
#   'regional': True,
#   'relative_price_difference': None,
#   'show_financing_checkbox': None,
#   'show_message_box': None,
#   'show_new_mileage': False,
#   'show_rsrp': True,
#   'show_thankyou_page': False,
#   'state': 'CA',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--k9Gij6CN--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/10/06/08/56/2018_tesla_model_3-pic-75754149688681297-1024x768.jpeg',
#   'time_on_market': None,
#   'total_price_change': None,
#   'tracking_params': {'dealer_group_unique_name': 'shift_cargurus',
#    'dealer_group_uuid': '88c7994e-2ed1-4892-b70f-55ba4c3e5540',
#    'dealer_name': 'Shift SF - Test Drives Delivered to You',
#    'dealer_unique_name': 'shift_sf_test_drives_deliveredto_you_two',
#    'dealer_uuid': 'a13d929d-f3f8-417c-9417-128dbb8ab28b',
#    'experience': 'regional',
#    'id_from_provider': '309463611',
#    'remote_dealer_id': '413397',
#    'remote_sku': 'c1691660',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None},
#   'trim': 'Standard',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EA3JF156817',
#   'vin': '5YJ3E1EA3JF156817',
#   'year': 2018}]

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for first result
results_json['search_results'][0]
# Out:
# {'accepts_leads': True,
#  'always_ask_for_zip': True,
#  'available_nationwide': False,
#  'badges': {'position0': None, 'position1': None},
#  'city': 'Fairfield',
#  'click_off': False,
#  'clickoff_url': 'https://www.carmax.com/car/21185133?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'cpl_value': 15,
#  'created_at': 1633066151,
#  'dealer_name': 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery',
#  'display_color': '',
#  'distance_from_origin': 41,
#  'email_opt_default': True,
#  'experience': 'local',
#  'href_target': '/listings/5YJ3E1EA0JF049255',
#  'id': 228637212,
#  'is_hot': False,
#  'lat': 38.27872113250454,
#  'listimate_category': None,
#  'listimate_text': None,
#  'listing_id': None,
#  'lon': -122.0043812304184,
#  'make': 'Tesla',
#  'mileage': '15,647 Miles',
#  'mileage_unformatted': 15647,
#  'model': 'Model 3',
#  'model_id': 2217,
#  'open_in_new_window': False,
#  'partner_type': 'dealer_direct',
#  'photo_urls': [],
#  'pre_check_thankyou': True,
#  'price': '$48,998',
#  'price_unformatted': 48998,
#  'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21185133/1.jpg?width=1024&watermark=LYCG_1a',
#  'provider': None,
#  'provider_group_id': 149,
#  'provider_id': 146,
#  'provider_name': 'carmax',
#  'quick_picks_eligible': False,
#  'recent_price_drop': False,
#  'regional': False,
#  'relative_price_difference': None,
#  'show_financing_checkbox': None,
#  'show_message_box': None,
#  'show_new_mileage': False,
#  'show_rsrp': True,
#  'show_thankyou_page': False,
#  'state': 'CA',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--owv7hvGJ--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21185133/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#  'time_on_market': None,
#  'total_price_change': None,
#  'tracking_params': {'dealer_group_unique_name': 'carmax',
#   'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520',
#   'dealer_name': 'CarMax Fairfield',
#   'dealer_unique_name': 'carmax_fairfield',
#   'dealer_uuid': '129aa2eb-3d7a-430c-a516-e65841530372',
#   'experience': 'local',
#   'id_from_provider': '5YJ3E1EA0JF049255',
#   'remote_dealer_id': '6048',
#   'remote_sku': '21185133',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None},
#  'trim': 'Long Range',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EA0JF049255',
#  'vin': '5YJ3E1EA0JF049255',
#  'year': 2018}

# %%
# model 
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
# mileage
results_json['search_results'][0]['mileage']
# Out:
# '15,647 Miles'

# %%
# year
results_json['search_results'][0]['year']
# Out:
# 2018

# %%
# dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Fairfield - Now Offering Curbside Pickup And Home Delivery'

# %%
# price
results_json['search_results'][0]['price']
# Out:
# '$48,998'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []

for result in result_items:
    
    # model
    model.append(result['model'])
    
    # mileage
    mileage.append(result['mileage'])
    
    # year
    year.append(result['year']) 
    
    # dealer name
    dealer_name.append(result['dealer_name']) 
    
    # price
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_df
# Out:
#       Model  ...    Price
# 0   Model 3  ...  $48,998
# 1   Model 3  ...  $44,450
# 2   Model X  ...  $86,800
# 3   Model 3  ...  $44,950
# 4   Model X  ...  $74,950
# 5   Model 3  ...  $50,450
# 6   Model 3  ...  $43,450
# 7   Model 3  ...  $42,950
# 8   Model 3  ...  $44,950
# 9   Model 3  ...  $48,950
# 10  Model Y  ...  $63,572
# 11  Model 3  ...  $47,998
# 12  Model 3  ...  $57,998
# 13  Model 3  ...  $46,950
# 14  Model 3  ...  $46,450
# 15  Model 3  ...  $49,998
# 16  Model 3  ...  $51,450
# 17  Model 3  ...  $42,861
# 18  Model 3  ...  $47,998
# 19  Model 3  ...  $39,500
#
# [20 rows x 5 columns]

# %%
tesla_df.to_excel('tesla_single_page.xlsx', index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}


model = []
mileage = []
year = []
dealer_name = []
price = []

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    # response variable for the get request
    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    # json object
    results_json = response.json()
    
    # result items (20 items for each page)
    result_items = results_json['search_results']
    
    for result in result_items:
    
        # model
        model.append(result['model'])

        # mileage
        mileage.append(result['mileage'])

        # year
        year.append(result['year']) 

        # dealer name
        dealer_name.append(result['dealer_name']) 

        # price
        price.append(result['price'])

# %%
tesla_multiple_df = pd.DataFrame({'Model': model, 'Mileage':mileage, 'Year':year, 'Dealer Name': dealer_name, 'Price': price})

# %%
tesla_multiple_df
# Out:
#       Model  ...    Price
# 0   Model 3  ...  $48,998
# 1   Model 3  ...  $44,450
# 2   Model X  ...  $86,800
# 3   Model 3  ...  $44,950
# 4   Model X  ...  $74,950
# ..      ...  ...      ...
# 95  Model 3  ...  $49,999
# 96  Model 3  ...  $44,499
# 97  Model 3  ...  $48,999
# 98  Model 3  ...  $46,999
# 99  Model 3  ...  $44,999
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx', index=False)
